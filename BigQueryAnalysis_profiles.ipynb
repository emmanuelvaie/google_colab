# %% [markdown]
# <a href="https://colab.research.google.com/github/emmanuelvaie/google_colab/blob/main/BigQueryAnalysis_profiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Setup
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

project = 'fluent-music-364313' # Project ID inserted based on the query results selected to explore
location = 'europe-west9' # Location inserted based on the query results selected to explore
client = bigquery.Client(project=project, location=location)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %%
query = """
SELECT * FROM import_boond.sonate_profiles where Ingestion_date='2022_12_05 14:17:44'; 
"""
job = client.query(query)

# %% [markdown]
# ## Reference SQL syntax from the original job
# Use the ```jobs.query```
# [method](https://cloud.google.com/bigquery/docs/reference/rest/v2/jobs/query) to
# return the SQL syntax from the job. This can be copied from the output cell
# below to edit the query now or in the future. Alternatively, you can use
# [this link](https://console.cloud.google.com/bigquery?j=fluent-music-364313:europe-west9:bquxjob_681ca93c_184a4051b54)
# back to BigQuery to edit the query within the BigQuery user interface.

# %%
print(job.query)
# Out:
# SELECT * FROM import_boond.sonate_profiles where Ingestion_date='2022_12_05 14:17:44';

# %% [markdown]
# # Result set loaded from BigQuery job as a DataFrame
# Query results are referenced from the Job ID ran from BigQuery and the query
# does not need to be re-run to explore results. The ```to_dataframe```
# [method](https://googleapis.dev/python/bigquery/latest/generated/google.cloud.bigquery.job.QueryJob.html#google.cloud.bigquery.job.QueryJob.to_dataframe)
# downloads the results to a Pandas DataFrame by using the BigQuery Storage API.
#
# To edit query syntax, you can do so from the BigQuery SQL editor or in the
# ```Optional:``` sections below.

# %%
# Running this code will read results from your previous job
results = job.to_dataframe()
results.head()
# Out:
# Warning: Total number of columns (46) exceeds max_columns (20). Falling back to pandas display.
#   Civilit__    Pr__nom        Nom                Type            Etape  \
# 0         M       Slim     SOUMRI  Consultant Externe  Vivier sourcing
# 1         M     Ahcene     OUKACI  Consultant Externe  Vivier sourcing
# 2         M  Siddharth     PANDEY  Consultant Externe  Vivier sourcing
# 3         M      Amine  El Harrak  Consultant Interne  Vivier sourcing
# 4         M      Ahmed  Ouiriemmi  Consultant Interne  Vivier sourcing
#
#                                 Titre  \
# 0                     freelancer java
# 1          Développeur .NET fullstack
# 2  Data Engineering, Cloud And DevOps
# 3      Dev FS Junior JAVA ANGULAR CDI
# 4         Indep ouvert au CDI .net/C#
#
#                                         Comp__tences Evaluation_Globale  \
# 0  html, npm, css, typescript, sql, apache, oracl...           Inconnue
# 1  html, bootstrap, css, typescript, sql, oracle,...           Inconnue
# 2                                               None           Inconnue
# 3    digital marketing, react, java, angular, master           Inconnue
# 4  agile, html, css, sql, oracle, sql server, jav...           Inconnue
#
#   Date_de_Naissance Nationalit__  ...   CV2   CV3   CV4   CV5 Mobilit__  \
# 0              None     Inconnue  ...  None  None  None  None  Inconnue
# 1              None     Inconnue  ...  None  None  None  None  Inconnue
# 2              None     Inconnue  ...  None  None  None  None  Inconnue
# 3              None     Inconnue  ...  None  None  None  None  Inconnue
# 4              None     Inconnue  ...  None  None  None  None  Inconnue
#
#   Langues   Domaines Secteurs  \
# 0    None  RD, Cloud     None
# 1    None         RD     None
# 2    None       None     None
# 3    None         RD     None
# 4    None         RD     None
#
#                                               Outils       Ingestion_date
# 0  html : 3, npm : 3, css : 3, typescript : 3, sq...  2022_12_05 14:17:44
# 1  html : 3, bootstrap : 3, css : 3, typescript :...  2022_12_05 14:17:44
# 2                                               None  2022_12_05 14:17:44
# 3  digital marketing : 3, react : 3, java : 3, an...  2022_12_05 14:17:44
# 4  agile : 3, html : 3, css : 3, sql : 3, oracle ...  2022_12_05 14:17:44
#
# [5 rows x 46 columns]

# %% [markdown]
# ## Show descriptive statistics using describe()
# Use the ```pandas DataFrame.describe()```
# [method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)
# to generate descriptive statistics. Descriptive statistics include those that
# summarize the central tendency, dispersion and shape of a dataset’s
# distribution, excluding ```NaN``` values. You may also use other Python methods
# to interact with your data.

# %%
results.describe(include='all')
# Out:
# Warning: Total number of columns (46) exceeds max_columns (20). Falling back to pandas display.
#        Civilit__  Pr__nom    Nom                Type   Etape   Titre  \
# count        978      978    902                 978     978     945
# unique         1      548    756                   2       9     515
# top            M  Mohamed  Ahmed  Consultant Externe  Vivier  Devops
# freq         978       34      4                 945     345      25
# mean         NaN      NaN    NaN                 NaN     NaN     NaN
# std          NaN      NaN    NaN                 NaN     NaN     NaN
# min          NaN      NaN    NaN                 NaN     NaN     NaN
# 25%          NaN      NaN    NaN                 NaN     NaN     NaN
# 50%          NaN      NaN    NaN                 NaN     NaN     NaN
# 75%          NaN      NaN    NaN                 NaN     NaN     NaN
# max          NaN      NaN    NaN                 NaN     NaN     NaN
#
#        Comp__tences Evaluation_Globale Date_de_Naissance Nationalit__  ...  \
# count           881                978                79          978  ...
# unique          788                  5                64            3  ...
# top              go           Inconnue      04 juin 2005     Inconnue  ...
# freq              6                619                 2          968  ...
# mean            NaN                NaN               NaN          NaN  ...
# std             NaN                NaN               NaN          NaN  ...
# min             NaN                NaN               NaN          NaN  ...
# 25%             NaN                NaN               NaN          NaN  ...
# 50%             NaN                NaN               NaN          NaN  ...
# 75%             NaN                NaN               NaN          NaN  ...
# max             NaN                NaN               NaN          NaN  ...
#
#                         CV2  \
# count                   186
# unique                  157
# top     Sonate_Hamza M.docx
# freq                      3
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN
#
#                                                       CV3  \
# count                                                  38
# unique                                                 35
# top     CodinGame - Docker,_Kubernetes,_Python_3_-_Sen...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                       CV4  \
# count                                                   9
# unique                                                  9
# top     CodinGame - Développeur_Python_-_Senior - Habi...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                       CV5 Mobilit__  \
# count                                                   3       972
# unique                                                  3        24
# top     CodinGame - Développeur_Full_Stack_Django_-_Se...  Inconnue
# freq                                                    1       899
# mean                                                  NaN       NaN
# std                                                   NaN       NaN
# min                                                   NaN       NaN
# 25%                                                   NaN       NaN
# 50%                                                   NaN       NaN
# 75%                                                   NaN       NaN
# max                                                   NaN       NaN
#
#                      Langues  Domaines          Secteurs       Outils  \
# count                    157       775                34          881
# unique                    17        20                20          798
# top     , Anglais : Inconnue  RD, Data  banque assurance  angular : 3
# freq                      78       196                 5            5
# mean                     NaN       NaN               NaN          NaN
# std                      NaN       NaN               NaN          NaN
# min                      NaN       NaN               NaN          NaN
# 25%                      NaN       NaN               NaN          NaN
# 50%                      NaN       NaN               NaN          NaN
# 75%                      NaN       NaN               NaN          NaN
# max                      NaN       NaN               NaN          NaN
#
#              Ingestion_date
# count                   978
# unique                    1
# top     2022_12_05 14:17:44
# freq                    978
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN
#
# [11 rows x 46 columns]

# %%
cols = results.columns

# %%
import pandas as pd
prf = pd.DataFrame()

# %%
for c in cols:
  nb_null = results[c].isna().sum()
  freq = results[c].value_counts()
  d = pd.DataFrame(data = {'nom_col': c, 'nb_null': [nb_null], 'freq': [freq]})
  #prf = prf.append(d)
  prf = pd.concat([prf,d])

# %%
prf.head()
# Out:
#      nom_col  nb_null                                               freq
# 0  Civilit__        0             M    978
# Name: Civilit__, dtype: int64
# 0    Pr__nom        0  Mohamed     34
# Youssef     18
# Hamza       14
# A...
# 0        Nom       76  Ahmed                    4
# MOHAMED            ...
# 0       Type        0  Consultant Externe    945
# Consultant Interne  ...
# 0      Etape        0  Vivier                         345
# No Go Sonat...

# %%
nb_records = len(results)
nb_records
# Out:
# 978

# %%
prf['pct_null'] = prf['nb_null'].apply(lambda x : 100 * x/nb_records)

# %%
prf
# Out:
#                                 nom_col  nb_null  \
# 0                             Civilit__        0
# 0                               Pr__nom        0
# 0                                   Nom       76
# 0                                  Type        0
# 0                                 Etape        0
# 0                                 Titre       33
# 0                          Comp__tences       97
# 0                    Evaluation_Globale        0
# 0                     Date_de_Naissance      899
# 0                          Nationalit__        0
# 0                        Disponibilit__        0
# 0                               Email_1      321
# 0                               Email_2      978
# 0                               Email_3      978
# 0                         T__l__phone_1      847
# 0                         T__l__phone_2      978
# 0                         T__l__phone_3      978
# 0                               Adresse      858
# 0                           Code_Postal      714
# 0                                 Ville      560
# 0                                  Pays      453
# 0                           Exp__rience      125
# 0                             Formation        0
# 0                             Dipl__mes      352
# 0                     Contrat_souhait__        0
# 0                        Salaire_Actuel        0
# 0  Salaire_Souhait_____Fourchette_basse        0
# 0  Salaire_Souhait_____Fourchette_haute        0
# 0                         Provenance_CV        0
# 0             Provenance_CV___Pr__cisez      978
# 0                          Commentaires      978
# 0                           Note___Date        0
# 0                          Note___Texte       22
# 0                     Date_de_cr__ation        0
# 0                        Responsable_RH        0
# 0                                   CV1      170
# 0                                   CV2      792
# 0                                   CV3      940
# 0                                   CV4      969
# 0                                   CV5      975
# 0                             Mobilit__        6
# 0                               Langues      821
# 0                              Domaines      203
# 0                              Secteurs      944
# 0                                Outils       97
# 0                        Ingestion_date        0
#
#                                                 freq    pct_null
# 0             M    978
# Name: Civilit__, dtype: int64    0.000000
# 0  Mohamed     34
# Youssef     18
# Hamza       14
# A...    0.000000
# 0  Ahmed                    4
# MOHAMED            ...    7.770961
# 0  Consultant Externe    945
# Consultant Interne  ...    0.000000
# 0  Vivier                         345
# No Go Sonat...    0.000000
# 0  Devops                               25
# Data E...    3.374233
# 0  go                                            ...    9.918200
# 0  Inconnue    619
# D           273
# C            3...    0.000000
# 0  04 juin 2005    2
# 31/07/1989      2
# 04/10/1981...   91.922290
# 0  Inconnue        968
# Non Français      7
# França...    0.000000
# 0  Inconnue         706
# Immédiat         137
# 3 mo...    0.000000
# 0  info@cherryblossom.digital         24
# khadija....   32.822086
# 0            Series([], Name: Email_2, dtype: int64)  100.000000
# 0            Series([], Name: Email_3, dtype: int64)  100.000000
# 0  +33773453449         2
# 33752971347          2
# ...   86.605317
# 0      Series([], Name: T__l__phone_2, dtype: int64)  100.000000
# 0      Series([], Name: T__l__phone_3, dtype: int64)  100.000000
# 0  30 rue d’Orléans 92200 Neuilly-sur-Seine www.s...   87.730061
# 0  92200     9
# 92000     9
# 78300     9
# 92400     ...   73.006135
# 0             Paris    418
# Name: Ville, dtype: int64   57.259714
# 0  France     418
# Maroc       51
# Tunisie     39
# A...   46.319018
# 0  6 à 10 ans          239
# > 10 ans            20...   12.781186
# 0         Bac+5    978
# Name: Formation, dtype: int64    0.000000
# 0  Ecole Marocaine des Sciences de l’Ingénieur , ...   35.991820
# 0  Freelance    967
# CDI           11
# Name: Contra...    0.000000
# 0  0        660
# 600       31
# 550       27
# 700    ...    0.000000
# 0  0        625
# 600       38
# 650       32
# 550    ...    0.000000
# 0  0         880
# 600         8
# 45000       8
# 550 ...    0.000000
# 0  Linkedin      958
# Cooptation     20
# Name: Prov...    0.000000
# 0  Series([], Name: Provenance_CV___Pr__cisez, dt...  100.000000
# 0       Series([], Name: Commentaires, dtype: int64)  100.000000
# 0  No date       338
# 2022/06/01     13
# 2021/10/28...    0.000000
# 0  LinkedIn : https://www.linkedin.com/in/edward-...    2.249489
# 0  1/6/2022      117
# 18/5/2021      18
# 23/2/2022 ...    0.000000
# 0  3    339
# 1    227
# 4    207
# 5    127
# 6     78
# N...    0.000000
# 0  CV Barthelemy Delemotte 2021 Dev Ops.pdf      ...   17.382413
# 0  Sonate_Hamza M.docx                           ...   80.981595
# 0  CodinGame - Docker,_Kubernetes,_Python_3_-_Sen...   96.114519
# 0  CodinGame - Développeur_Python_-_Senior - Habi...   99.079755
# 0  CodinGame - Développeur_Full_Stack_Django_-_Se...   99.693252
# 0  Inconnue                                      ...    0.613497
# 0  , Anglais : Inconnue                          ...   83.946830
# 0  RD, Data                          196
# RD      ...   20.756646
# 0  banque assurance            5
# engie           ...   96.523517
# 0  angular : 3                                   ...    9.918200
# 0  2022_12_05 14:17:44    978
# Name: Ingestion_dat...    0.000000
