# %% [markdown]
# <a href="https://colab.research.google.com/github/emmanuelvaie/google_colab/blob/main/BigQueryAnalysis_profiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Setup
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

project = 'fluent-music-364313' # Project ID inserted based on the query results selected to explore
location = 'europe-west9' # Location inserted based on the query results selected to explore
client = bigquery.Client(project=project, location=location)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %%
query = """
SELECT * FROM import_boond.sonate_profiles where Ingestion_date='2022-12-02 13:32:05.215497'; 
"""
job = client.query(query)

# %% [markdown]
# ## Reference SQL syntax from the original job
# Use the ```jobs.query```
# [method](https://cloud.google.com/bigquery/docs/reference/rest/v2/jobs/query) to
# return the SQL syntax from the job. This can be copied from the output cell
# below to edit the query now or in the future. Alternatively, you can use
# [this link](https://console.cloud.google.com/bigquery?j=fluent-music-364313:europe-west9:bquxjob_681ca93c_184a4051b54)
# back to BigQuery to edit the query within the BigQuery user interface.

# %%
print(job.query)
# Out:
# SELECT * FROM import_boond.sonate_profiles where Ingestion_date='2022-12-02 13:32:05.215497';

# %% [markdown]
# # Result set loaded from BigQuery job as a DataFrame
# Query results are referenced from the Job ID ran from BigQuery and the query
# does not need to be re-run to explore results. The ```to_dataframe```
# [method](https://googleapis.dev/python/bigquery/latest/generated/google.cloud.bigquery.job.QueryJob.html#google.cloud.bigquery.job.QueryJob.to_dataframe)
# downloads the results to a Pandas DataFrame by using the BigQuery Storage API.
#
# To edit query syntax, you can do so from the BigQuery SQL editor or in the
# ```Optional:``` sections below.

# %%
# Running this code will read results from your previous job
results = job.to_dataframe()
results.head()
# Out:
# Warning: Total number of columns (46) exceeds max_columns (20). Falling back to pandas display.
#   Civilit__   Pr__nom        Nom                Type            Etape  \
# 0         M    Hocine  MEZGHICHE  Consultant Externe  Vivier sourcing
# 1         M   Jérémie   Dourneau  Consultant Externe  Vivier sourcing
# 2         M    Johnny  KNOBLAUCH  Consultant Externe  Vivier sourcing
# 3         M      Slim     SOUMRI  Consultant Externe  Vivier sourcing
# 4         M  Mustapha     ALIANE  Consultant Externe  Vivier sourcing
#
#                Titre                                       Comp__tences  \
# 0  Big Data Engineer  scala, machine learning, aws, master, big data...
# 1     Data ingénieur  hadoop, python, scala, spark, oracle, agile, e...
# 2     .net developer  management, architect, graphql, bi, saas, type...
# 3    freelancer java  docker, npm, javascript, apache, kubernetes, g...
# 4    freelancer JAVA  apache, css, master, xml, sql, data, api, reac...
#
#   Evaluation_Globale Date_de_Naissance Nationalit__  ...   CV2   CV3   CV4  \
# 0           Inconnue              None     Inconnue  ...  None  None  None
# 1           Inconnue              None     Inconnue  ...  None  None  None
# 2           Inconnue              None     Inconnue  ...  None  None  None
# 3           Inconnue              None     Inconnue  ...  None  None  None
# 4           Inconnue              None     Inconnue  ...  None  None  None
#
#     CV5 Mobilit__ Langues     Domaines Secteurs  \
# 0  None  Inconnue    None  Cloud, Data     None
# 1  None  Inconnue    None         Data     None
# 2  None  Inconnue    None         Data     None
# 3  None  Inconnue    None           RD     None
# 4  None  Inconnue    None     RD, Data     None
#
#                                               Outils  \
# 0  scala : 3, machine learning : 3, aws : 3, mast...
# 1  hadoop : 3, python : 3, scala : 3, spark : 3, ...
# 2  management : 3, architect : 3, graphql : 3, bi...
# 3  docker : 3, npm : 3, javascript : 3, apache : ...
# 4  apache : 5, css : 5, master : 5, xml : 5, sql ...
#
#                Ingestion_date
# 0  2022-12-02 13:32:05.215497
# 1  2022-12-02 13:32:05.215497
# 2  2022-12-02 13:32:05.215497
# 3  2022-12-02 13:32:05.215497
# 4  2022-12-02 13:32:05.215497
#
# [5 rows x 46 columns]

# %% [markdown]
# ## Show descriptive statistics using describe()
# Use the ```pandas DataFrame.describe()```
# [method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)
# to generate descriptive statistics. Descriptive statistics include those that
# summarize the central tendency, dispersion and shape of a dataset’s
# distribution, excluding ```NaN``` values. You may also use other Python methods
# to interact with your data.

# %%
results.describe(include='all')
# Out:
# Warning: Total number of columns (46) exceeds max_columns (20). Falling back to pandas display.
#        Civilit__  Pr__nom    Nom                Type   Etape   Titre  \
# count        977      977    901                 977     977     944
# unique         1      547    755                   2       9     514
# top            M  Mohamed  Ahmed  Consultant Externe  Vivier  Devops
# freq         977       34      4                 944     345      25
# mean         NaN      NaN    NaN                 NaN     NaN     NaN
# std          NaN      NaN    NaN                 NaN     NaN     NaN
# min          NaN      NaN    NaN                 NaN     NaN     NaN
# 25%          NaN      NaN    NaN                 NaN     NaN     NaN
# 50%          NaN      NaN    NaN                 NaN     NaN     NaN
# 75%          NaN      NaN    NaN                 NaN     NaN     NaN
# max          NaN      NaN    NaN                 NaN     NaN     NaN
#
#                                              Comp__tences Evaluation_Globale  \
# count                                                 781                977
# unique                                                666                  5
# top     apache, management, aws lambda, aws, perl, php...           Inconnue
# freq                                                    3                619
# mean                                                  NaN                NaN
# std                                                   NaN                NaN
# min                                                   NaN                NaN
# 25%                                                   NaN                NaN
# 50%                                                   NaN                NaN
# 75%                                                   NaN                NaN
# max                                                   NaN                NaN
#
#        Date_de_Naissance Nationalit__  ...                  CV2  \
# count                 78          977  ...                  186
# unique                63            3  ...                  157
# top           19/08/1990     Inconnue  ...  Sonate_Hamza M.docx
# freq                   2          967  ...                    3
# mean                 NaN          NaN  ...                  NaN
# std                  NaN          NaN  ...                  NaN
# min                  NaN          NaN  ...                  NaN
# 25%                  NaN          NaN  ...                  NaN
# 50%                  NaN          NaN  ...                  NaN
# 75%                  NaN          NaN  ...                  NaN
# max                  NaN          NaN  ...                  NaN
#
#                                                       CV3  \
# count                                                  38
# unique                                                 35
# top     CodinGame - Docker,_Kubernetes,_Python_3_-_Sen...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                       CV4  \
# count                                                   9
# unique                                                  9
# top     CodinGame - Développeur_Python_-_Senior - Habi...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                       CV5 Mobilit__  \
# count                                                   3       971
# unique                                                  3        24
# top     CodinGame - Développeur_Full_Stack_Django_-_Se...  Inconnue
# freq                                                    1       898
# mean                                                  NaN       NaN
# std                                                   NaN       NaN
# min                                                   NaN       NaN
# 25%                                                   NaN       NaN
# 50%                                                   NaN       NaN
# 75%                                                   NaN       NaN
# max                                                   NaN       NaN
#
#                      Langues  Domaines          Secteurs  \
# count                    157       771                34
# unique                    17        19                20
# top     , Anglais : Inconnue  RD, Data  banque assurance
# freq                      78       211                 5
# mean                     NaN       NaN               NaN
# std                      NaN       NaN               NaN
# min                      NaN       NaN               NaN
# 25%                      NaN       NaN               NaN
# 50%                      NaN       NaN               NaN
# 75%                      NaN       NaN               NaN
# max                      NaN       NaN               NaN
#
#                                                    Outils  \
# count                                                 781
# unique                                                672
# top     apache : 3, management : 3, aws lambda : 3, aw...
# freq                                                    3
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                     Ingestion_date
# count                          977
# unique                           1
# top     2022-12-02 13:32:05.215497
# freq                           977
# mean                           NaN
# std                            NaN
# min                            NaN
# 25%                            NaN
# 50%                            NaN
# 75%                            NaN
# max                            NaN
#
# [11 rows x 46 columns]

# %%
cols = results.columns

# %%
import pandas as pd
prf = pd.DataFrame()

# %%
for c in cols:
  nb_null = results[c].isna().sum()
  freq = results[c].value_counts()
  d = pd.DataFrame(data = {'nom_col': c, 'nb_null': [nb_null], 'freq': [freq]})
  #prf = prf.append(d)
  prf = pd.concat([prf,d])

# %%
prf.head()
# Out:
#      nom_col  nb_null                                               freq
# 0  Civilit__        0             M    977
# Name: Civilit__, dtype: int64
# 0    Pr__nom        0  Mohamed        34
# Youssef        18
# Ahmed     ...
# 0        Nom       76  Ahmed                 4
# TAHAR                 ...
# 0       Type        0  Consultant Externe    944
# Consultant Interne  ...
# 0      Etape        0  Vivier                         345
# No Go Sonat...

# %%
nb_records = len(results)
nb_records
# Out:
# 977

# %%
prf['pct_null'] = prf['nb_null'].apply(lambda x : 100 * x/nb_records)

# %%
prf
# Out:
#                                 nom_col  nb_null  \
# 0                             Civilit__        0
# 0                               Pr__nom        0
# 0                                   Nom       76
# 0                                  Type        0
# 0                                 Etape        0
# 0                                 Titre       33
# 0                          Comp__tences      196
# 0                    Evaluation_Globale        0
# 0                     Date_de_Naissance      899
# 0                          Nationalit__        0
# 0                        Disponibilit__        0
# 0                               Email_1      319
# 0                               Email_2      977
# 0                               Email_3      977
# 0                         T__l__phone_1      846
# 0                         T__l__phone_2      977
# 0                         T__l__phone_3      977
# 0                               Adresse      856
# 0                           Code_Postal      711
# 0                                 Ville      558
# 0                                  Pays      450
# 0                           Exp__rience      110
# 0                             Formation        0
# 0                             Dipl__mes      350
# 0                     Contrat_souhait__        0
# 0                        Salaire_Actuel        0
# 0  Salaire_Souhait_____Fourchette_basse        0
# 0  Salaire_Souhait_____Fourchette_haute        0
# 0                         Provenance_CV        0
# 0             Provenance_CV___Pr__cisez      977
# 0                          Commentaires      977
# 0                           Note___Date        0
# 0                          Note___Texte       22
# 0                     Date_de_cr__ation        0
# 0                        Responsable_RH        0
# 0                                   CV1      170
# 0                                   CV2      791
# 0                                   CV3      939
# 0                                   CV4      968
# 0                                   CV5      974
# 0                             Mobilit__        6
# 0                               Langues      820
# 0                              Domaines      206
# 0                              Secteurs      943
# 0                                Outils      196
# 0                        Ingestion_date        0
#
#                                                 freq    pct_null
# 0             M    977
# Name: Civilit__, dtype: int64    0.000000
# 0  Mohamed        34
# Youssef        18
# Ahmed     ...    0.000000
# 0  Ahmed                 4
# TAHAR                 ...    7.778915
# 0  Consultant Externe    944
# Consultant Interne  ...    0.000000
# 0  Vivier                         345
# No Go Sonat...    0.000000
# 0  Devops                         25
# Data Enginee...    3.377687
# 0  apache, management, aws lambda, aws, perl, php...   20.061412
# 0  Inconnue    619
# D           273
# C            3...    0.000000
# 0  19/08/1990           2
# 30/11/1990           2
# ...   92.016377
# 0  Inconnue        967
# Non Français      7
# França...    0.000000
# 0  Inconnue                         705
# 3 mois a/...    0.000000
# 0  info@cherryblossom.digital        24
# khadija.h...   32.650972
# 0            Series([], Name: Email_2, dtype: int64)  100.000000
# 0            Series([], Name: Email_3, dtype: int64)  100.000000
# 0  +33622056091          2
# +33773453449          ...   86.591607
# 0      Series([], Name: T__l__phone_2, dtype: int64)  100.000000
# 0      Series([], Name: T__l__phone_3, dtype: int64)  100.000000
# 0  30 rue d’Orléans 92200 Neuilly-sur-Seine www.s...   87.615148
# 0  92000     9
# 92200     9
# 78300     9
# 92400     ...   72.773797
# 0             Paris    419
# Name: Ville, dtype: int64   57.113613
# 0  France     419
# Maroc       51
# Tunisie     40
# A...   46.059365
# 0  Pas d'expérience    617
# 6 à 10 ans           8...   11.258956
# 0         Bac+5    977
# Name: Formation, dtype: int64    0.000000
# 0  ingénieur en,                                 ...   35.823951
# 0  Freelance    966
# CDI           11
# Name: Contra...    0.000000
# 0  0         659
# 144000     31
# 132000     27
# 1680...    0.000000
# 0  0         624
# 144000     38
# 156000     32
# 1320...    0.000000
# 0  0         879
# 144000      8
# 45000       8
# 1320...    0.000000
# 0  Linkedin      957
# Cooptation     20
# Name: Prov...    0.000000
# 0  Series([], Name: Provenance_CV___Pr__cisez, dt...  100.000000
# 0       Series([], Name: Commentaires, dtype: int64)  100.000000
# 0  No date       337
# 2022/06/01     13
# 2021/10/28...    0.000000
# 0  **LKD** :  **Tel** :   **Salaire** :          ...    2.251791
# 0  1/6/2022      117
# 18/5/2021      18
# 23/2/2022 ...    0.000000
# 0  3    339
# 1    227
# 4    206
# 5    127
# 6     78
# N...    0.000000
# 0  Irina MATHERN.doc                2
# AMAL MALLOU...   17.400205
# 0  Sonate_Hamza M.docx                           ...   80.962129
# 0  CodinGame - Docker,_Kubernetes,_Python_3_-_Sen...   96.110542
# 0  CodinGame - Développeur_Python_-_Senior - Habi...   99.078813
# 0  CodinGame - Développeur_Full_Stack_Django_-_Se...   99.692938
# 0  Inconnue                                      ...    0.614125
# 0  , Anglais : Inconnue                          ...   83.930399
# 0  RD, Data                          211
# RD      ...   21.084954
# 0  banque assurance            5
# engie           ...   96.519959
# 0  apache : 3, management : 3, aws lambda : 3, aw...   20.061412
# 0  2022-12-02 13:32:05.215497    977
# Name: Ingest...    0.000000
